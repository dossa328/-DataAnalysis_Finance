# %% [markdown]
# * 한국거래소(KRX) 전체 종목 분석
# *
# * FinanceDataReader를 통한 KRX 전체 종목 수집
#
#     * to_csv("파일명", index=False) : csv 파일로 저장하기
#     * read_csv("파일명") : csv 파일 불러오기
# * Pandas를 통한 파일 저장과 불러오기
#
#     * shape를 통한 행과 열의 수 보기
#     * head, tail, sample 을 통한 일부 데이터 가져오기
# * DataFrame의 info(), describe() 등을 통한 요약과 기술통계 값 구하기
#
#     * info()
#     * describe()
#     * nunique()
#     * index
#     * columns
#     * values
# * Pandas의 DataFrame과 Series의 이해
#
#     * Series : 1차원 벡터구조
#     * DataFrame : 2차원 행렬구조
# * 색인하기
#
#     * [컬럼]
#     * .loc[행]
#     * .loc[행, 열]
#     * .loc[조건식, 열]
# * DataFrame의 데이터 타입 이해하기
#
# * 날짜 데이터의 변환
# * DataFrame 다루기
#
#     * 열(column) 인덱싱
#     * 행(index) 인덱싱
#     * 행, 열 인덱싱
#     * 정렬하기 : sort_values 사용하기
#     * 조건식 사용하기
# * 빈도수 구하기
#
#     * 한 개의 변수 : series.value_counts()
#     * 두 개의 변수 : pd.crosstab()
# * groupby 와 pivot_table
#
# * 다양한 연산식의 사용

# %%
# 데이터 분석을 위해 pandas, 시각화를 위해 seaborn 불러오기
import pandas as pd
import seaborn as sns
import numpy as np
# 수치계산을 위한 numpy

# %% [markdown]
# ## 4. FinanceDataReader로 수집한 전체 종목 불러오기
# * 한국 주식 가격, 미국 주식 가격, 지수, 환율, 암호화폐 가격, 종목 리스팅 등 금융 데이터 수집 라이브러리

# %%
# 이전 강좌에서 to_csv 로 저장해둔 krx.csv 파일을 pd.read_csv로 불러옵니다

df= pd.read_csv("krx.csv")
df.shape
# Out:
# (2612, 10)

# %% [markdown]
# ### 일부 데이터만 가져오기

# %%
# head 로 위에있는 데이터 일부만 가져옵니다.
df.head()
# shift+tab = 도움말
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S    특수 목적용 기계 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth      Representative                       HomePage Region
# 0         03월  박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1         12월                 이현우         http://www.ajnet.co.kr  서울특별시
# 2         12월   채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                 정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                 김영주     http://www.apsystems.co.kr    경기도

# %%
# tail로 아래있는 데이터 일부만 가져옵니다
df.tail()
# Out:
#       Symbol  Market     Name                    Sector  \
# 2607  000547   KOSPI  흥국화재2우B                       NaN
# 2608  000545   KOSPI    흥국화재우                       NaN
# 2609  003280   KOSPI     흥아해운                    해상 운송업
# 2610  037440  KOSDAQ       희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 2611  238490  KOSDAQ       힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 2607                             NaN         NaN         NaN
# 2608                             NaN         NaN         NaN
# 2609                  외항화물운송업(케미컬탱커)  1976-06-29         12월
# 2610                       설계 및 감리용역  2000-02-03         12월
# 2611  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월
#
#                  Representative                HomePage Region
# 2607                        NaN                     NaN    NaN
# 2608                        NaN                     NaN    NaN
# 2609                        이환구  http://www.heung-a.com  서울특별시
# 2610  정영균, 이목운, 허철호, 염두성 (각자대표)   http://www.heerim.com  서울특별시
# 2611                        김주환   http://www.hims.co.kr  인천광역시

# %%
# sample을 사용하면 랜덤하게()안의 갯수만큼 가져옵니다.
# 기본값은 1임
df.sample()
# Out:
#       Symbol Market Name                 Sector     Industry ListingDate  \
# 2232  005690  KOSPI  파미셀  기초 의약물질 및 생물학적 제제 제조업  줄기세포치료제,화장품  1988-05-20
#
#      SettleMonth Representative                   HomePage Region
# 2232         12월            김현수  http://www.pharmicell.com  서울특별시

# %% [markdown]
# ## 5. 데이터 요약하기

# %%
# info로 요약 데이터를 봅니다.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2612 entries, 0 to 2611
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          2612 non-null   object
#  1   Market          2612 non-null   object
#  2   Name            2612 non-null   object
#  3   Sector          2411 non-null   object
#  4   Industry        2392 non-null   object
#  5   ListingDate     2411 non-null   object
#  6   SettleMonth     2411 non-null   object
#  7   Representative  2411 non-null   object
#  8   HomePage        2239 non-null   object
#  9   Region          2411 non-null   object
# dtypes: object(10)
# memory usage: 204.2+ KB

# %%
# describe 로 기술 통계값을 본다
df.describe()
# Out:
#         Symbol  Market    Name         Sector Industry ListingDate  \
# count     2612    2612    2612           2411     2392        2411
# unique    2612       3    2612            158     2240        1777
# top     041590  KOSDAQ  와이아이케이  특수 목적용 기계 제조업   기업인수합병  1996-07-03
# freq         1    1471       1            141       37           8
#
#        SettleMonth Representative                 HomePage Region
# count         2411           2411                     2239   2411
# unique           9           2297                     2218     21
# top            12월            김상우  http://www.moorim.co.kr  서울특별시
# freq          2351              4                        2    969

# %%
# 중복을 제외한 unique값의 갯수를 봅니다
df.nunique()
# Out:
# Symbol            2612
# Market               3
# Name              2612
# Sector             158
# Industry          2240
# ListingDate       1777
# SettleMonth          9
# Representative    2297
# HomePage          2218
# Region              21
# dtype: int64

# %%
# index값 보기
df.index
# Out:
# RangeIndex(start=0, stop=2612, step=1)

# %%
# 컬럼값 보기
df.columns
# Out:
# Index(['Symbol', 'Market', 'Name', 'Sector', 'Industry', 'ListingDate',
#        'SettleMonth', 'Representative', 'HomePage', 'Region'],
#       dtype='object')

# %%
# 값만 가져오기
df.values
# pd.DataFrame(df.values)
# Out:
# array([['060310', 'KOSDAQ', '3S', ..., '박종익, 김세완 (각자 대표이사)',
#         'http://www.3sref.com', '서울특별시'],
#        ['095570', 'KOSPI', 'AJ네트웍스', ..., '이현우',
#         'http://www.ajnet.co.kr', '서울특별시'],
#        ['006840', 'KOSPI', 'AK홀딩스', ..., '채형석, 이석주(각자 대표이사)',
#         'http://www.aekyunggroup.co.kr', '서울특별시'],
#        ...,
#        ['003280', 'KOSPI', '흥아해운', ..., '이환구', 'http://www.heung-a.com',
#         '서울특별시'],
#        ['037440', 'KOSDAQ', '희림', ..., '정영균, 이목운, 허철호, 염두성 (각자대표)',
#         'http://www.heerim.com', '서울특별시'],
#        ['238490', 'KOSDAQ', '힘스', ..., '김주환', 'http://www.hims.co.kr',
#         '인천광역시']], dtype=object)

# %% [markdown]
# ##  6 데이터 색인하기
# ### 6.1 Series

# %%
# name 컬럼 1개만 가져오기
df["Name"]
# Out:
# 0            3S
# 1        AJ네트웍스
# 2         AK홀딩스
# 3        APS홀딩스
# 4         AP시스템
#          ...
# 2607    흥국화재2우B
# 2608      흥국화재우
# 2609       흥아해운
# 2610         희림
# 2611         힘스
# Name: Name, Length: 2612, dtype: object

# %%
# df["Name"]의 type을 봅니다.
type(df["Name"])
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#       Symbol  Market     Name                    Sector  \
# 0     060310  KOSDAQ       3S             특수 목적용 기계 제조업
# 1     095570   KOSPI   AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI    AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ   APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ    AP시스템             특수 목적용 기계 제조업
# ...      ...     ...      ...                       ...
# 2607  000547   KOSPI  흥국화재2우B                       NaN
# 2608  000545   KOSPI    흥국화재우                       NaN
# 2609  003280   KOSPI     흥아해운                    해상 운송업
# 2610  037440  KOSDAQ       희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 2611  238490  KOSDAQ       힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                               지주사업  1999-08-11         12월
# 3                        인터넷 트래픽 솔루션  2001-12-04         12월
# 4                        디스플레이 제조 장비  2017-04-07         12월
# ...                              ...         ...         ...
# 2607                             NaN         NaN         NaN
# 2608                             NaN         NaN         NaN
# 2609                  외항화물운송업(케미컬탱커)  1976-06-29         12월
# 2610                       설계 및 감리용역  2000-02-03         12월
# 2611  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월
#
#                  Representative                       HomePage Region
# 0            박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1                           이현우         http://www.ajnet.co.kr  서울특별시
# 2             채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3                           정기로   http://www.apsholdings.co.kr    경기도
# 4                           김영주     http://www.apsystems.co.kr    경기도
# ...                         ...                            ...    ...
# 2607                        NaN                            NaN    NaN
# 2608                        NaN                            NaN    NaN
# 2609                        이환구         http://www.heung-a.com  서울특별시
# 2610  정영균, 이목운, 허철호, 염두성 (각자대표)          http://www.heerim.com  서울특별시
# 2611                        김주환          http://www.hims.co.kr  인천광역시
#
# [2612 rows x 10 columns]

# %%
# 0번째 행마 ㄴ가져옵니다. 행인덱스를 가져올때는 .loc을 사용합니다
# loc은 위치(locate)를 의미합니다

print(df.loc[0])
print(type(df.loc[0]))
# Out:
# Symbol                          060310
# Market                          KOSDAQ
# Name                                3S
# Sector                   특수 목적용 기계 제조업
# Industry                   반도체 웨이퍼 캐리어
# ListingDate                 2002-04-23
# SettleMonth                        03월
# Representative      박종익, 김세완 (각자 대표이사)
# HomePage          http://www.3sref.com
# Region                           서울특별시
# Name: 0, dtype: object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ### 6.2 DataFrame

# %%
# df 변수의 타입을 봅니다.
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# 여러 컬럼을 지정할 때는 리스트 형태로 묶어주어야 합니다
# 2차원 행렬은 대괄호가 [] 2개 있다는 것을 명심
df[["Name","Symbol"]].head()
# Out:
#      Name  Symbol
# 0      3S  060310
# 1  AJ네트웍스  095570
# 2   AK홀딩스  006840
# 3  APS홀딩스  054620
# 4   AP시스템  265520

# %%
# 여러개의 행을 가져올때도 [] 대괄호를 통해 리스트 형태로 묶어줍니다
df.loc[[0,1,7,8,10]]
# Out:
#     Symbol  Market     Name           Sector             Industry ListingDate  \
# 0   060310  KOSDAQ       3S    특수 목적용 기계 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1   095570   KOSPI   AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 7   282330   KOSPI   BGF리테일           종합 소매업              체인화 편의점  2017-12-08
# 8   138930   KOSPI  BNK금융지주           기타 금융업               금융지주회사  2011-03-30
# 10  001465   KOSPI     BYC우              NaN                  NaN         NaN
#
#    SettleMonth      Representative                  HomePage Region
# 0          03월  박종익, 김세완 (각자 대표이사)      http://www.3sref.com  서울특별시
# 1          12월                 이현우    http://www.ajnet.co.kr  서울특별시
# 7          12월                 이건준  http://www.bgfretail.com  서울특별시
# 8          12월                 김지완      http://www.bnkfg.com  부산광역시
# 10         NaN                 NaN                       NaN    NaN

# %%
# 1개의 컬럼을 가져올 때도 대괄호 [] 2개를 써서 리스트 형태로 묵어주게 되면 데이터 프레임 형태로 반환됩니다.
# "Name"을 데이터 프레임으로 가져옵니다
type(df[["Name"]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 6.3 loc를 통한 서브셋 가져오기

# %%
# 행과 열 함게 가져오기
# .loc[행, 열]
# Name을 가져오고, 0번째 행을 다시 가져오는 2번의 IO가 발생함
df["Name"][0]
# Out:
# '3S'

# %%
# 한번의 쿼리로 가져옴. (추천)
df.loc[0, "Name"]
# Out:
# '3S'

# %%
# 여러개의 행과 하나의 컬럼 가져오기
# .loc[행, 열]
df.loc[[0, 1, 2], "Name"]
# Out:
# 0        3S
# 1    AJ네트웍스
# 2     AK홀딩스
# Name: Name, dtype: object

# %%
# 여러개의 행과 여러개의 컬럼 가져오기
df.loc[[0,1,2],["Name", "Symbol"]]
# Out:
#      Name  Symbol
# 0      3S  060310
# 1  AJ네트웍스  095570
# 2   AK홀딩스  006840

# %% [markdown]
# ### 6.4 Boolean Indexing
# * 결과값이 True, False bool 형태로 반환되기 때문에 boolean indexing이라고 부릅니다
# * boolean indexing을 사용하 특정 조건식을 만족하는 데이터를 서브셋으로 가져옵니다

# %%
# 카카오를 찾습니다
df[df["Name"] == "카카오"]
# Out:
#       Symbol Market Name                            Sector         Industry  \
# 2009  035720  KOSPI  카카오  자료처리, 호스팅, 포털 및 기타 인터넷 정보매개 서비스업  인터넷 서비스(인터넷 광고)
#
#      ListingDate SettleMonth Representative                  HomePage   Region
# 2009  2017-07-10         12월       여민수, 조수용  http://www.kakaocorp.com  제주특별자치도

# %%
# and => &
# or => |

# %%
# 서울 특별시에 소재지를 두고 있는 KOSPI 종목의 종목명과 심볼을 가져옵니다.
# .loc[행, 열]
# .loc[조건식, 열]
df.loc[(df["Region"] == "서울특별시") & (df["Market"] == "KOSPI"), ["Symbol", "Name"]]
# Out:
#       Symbol    Name
# 1     095570  AJ네트웍스
# 2     006840   AK홀딩스
# 6     027410     BGF
# 7     282330  BGF리테일
# 9     001460     BYC
# ...      ...     ...
# 2596  079980     휴비스
# 2598  005010     휴스틸
# 2602  069260     휴켐스
# 2606  000540    흥국화재
# 2609  003280    흥아해운
#
# [407 rows x 2 columns]

# %% [markdown]
# ## 7. 파생 변수 만들기

# %%
# pd.to_datetime 을 통해 데이터의 타입을 변환합니다
df["ListingDate"] = pd.to_datetime(df["ListingDate"])

# %%
# ListingYear 파생변수 만들기
df["ListingYear"] = df["ListingDate"].dt.year

# %%
df.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S    특수 목적용 기계 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth      Representative                       HomePage Region  \
# 0         03월  박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1         12월                 이현우         http://www.ajnet.co.kr  서울특별시
# 2         12월   채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                 정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                 김영주     http://www.apsystems.co.kr    경기도
#
#    ListingYear
# 0       2002.0
# 1       2015.0
# 2       1999.0
# 3       2001.0
# 4       2017.0

# %%
type(np.nan)
# Out:
# float

# %%
# df[["ListingDate", "ListingYear"]].describe()
df[["ListingDate", "ListingYear"]].dtypes
# NAN = 결측치 , 때문에 datetime64가 float64로 설정됨.
# Out:
# ListingDate    datetime64[ns]
# ListingYear           float64
# dtype: object

# %% [markdown]
# ## 8. 데이터 시각화 툴 소개

# %% [markdown]
# ### 8.1 matplotlib
# * https://matplotlib.org/3.1.1/gallery/showcase/anatomy.html

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator, MultipleLocator, FuncFormatter

np.random.seed(19680801)

X = np.linspace(0.5, 3.5, 100)
Y1 = 3+np.cos(X)
Y2 = 1+np.cos(1+X/0.75)/2
Y3 = np.random.uniform(Y1, Y2, len(X))

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(1, 1, 1, aspect=1)


def minor_tick(x, pos):
    if not x % 1.0:
        return ""
    return "%.2f" % x

ax.xaxis.set_major_locator(MultipleLocator(1.000))
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_major_locator(MultipleLocator(1.000))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.xaxis.set_minor_formatter(FuncFormatter(minor_tick))

ax.set_xlim(0, 4)
ax.set_ylim(0, 4)

ax.tick_params(which='major', width=1.0)
ax.tick_params(which='major', length=10)
ax.tick_params(which='minor', width=1.0, labelsize=10)
ax.tick_params(which='minor', length=5, labelsize=10, labelcolor='0.25')

ax.grid(linestyle="--", linewidth=0.5, color='.25', zorder=-10)

ax.plot(X, Y1, c=(0.25, 0.25, 1.00), lw=2, label="Blue signal", zorder=10)
ax.plot(X, Y2, c=(1.00, 0.25, 0.25), lw=2, label="Red signal")
ax.plot(X, Y3, linewidth=0,
        marker='o', markerfacecolor='w', markeredgecolor='k')

ax.set_title("Anatomy of a figure", fontsize=20, verticalalignment='bottom')
ax.set_xlabel("X axis label")
ax.set_ylabel("Y axis label")

ax.legend()


def circle(x, y, radius=0.15):
    from matplotlib.patches import Circle
    from matplotlib.patheffects import withStroke
    circle = Circle((x, y), radius, clip_on=False, zorder=10, linewidth=1,
                    edgecolor='black', facecolor=(0, 0, 0, .0125),
                    path_effects=[withStroke(linewidth=5, foreground='w')])
    ax.add_artist(circle)


def text(x, y, text):
    ax.text(x, y, text, backgroundcolor="white",
            ha='center', va='top', weight='bold', color='blue')


# Minor tick
circle(0.50, -0.10)
text(0.50, -0.32, "Minor tick label")

# Major tick
circle(-0.03, 4.00)
text(0.03, 3.80, "Major tick")

# Minor tick
circle(0.00, 3.50)
text(0.00, 3.30, "Minor tick")

# Major tick label
circle(-0.15, 3.00)
text(-0.15, 2.80, "Major tick label")

# X Label
circle(1.80, -0.27)
text(1.80, -0.45, "X axis label")

# Y Label
circle(-0.27, 1.80)
text(-0.27, 1.6, "Y axis label")

# Title
circle(1.60, 4.13)
text(1.60, 3.93, "Title")

# Blue plot
circle(1.75, 2.80)
text(1.75, 2.60, "Line\n(line plot)")

# Red plot
circle(1.20, 0.60)
text(1.20, 0.40, "Line\n(line plot)")

# Scatter plot
circle(3.20, 1.75)
text(3.20, 1.55, "Markers\n(scatter plot)")

# Grid
circle(3.00, 3.00)
text(3.00, 2.80, "Grid")

# Legend
circle(3.70, 3.80)
text(3.70, 3.60, "Legend")

# Axes
circle(0.5, 0.5)
text(0.5, 0.3, "Axes")

# Figure
circle(-0.3, 0.65)
text(-0.3, 0.45, "Figure")

color = 'blue'
ax.annotate('Spines', xy=(4.0, 0.35), xytext=(3.3, 0.5),
            weight='bold', color=color,
            arrowprops=dict(arrowstyle='->',
                            connectionstyle="arc3",
                            color=color))

ax.annotate('', xy=(3.15, 0.0), xytext=(3.45, 0.45),
            weight='bold', color=color,
            arrowprops=dict(arrowstyle='->',
                            connectionstyle="arc3",
                            color=color))

ax.text(4.0, -0.4, "Made with http://matplotlib.org",
        fontsize=10, ha="right", color='.5')

plt.show()

# %% [markdown]
# ### 8.2 seaborn
# * http://seaborn.pydata.org/index.html

# %% [markdown]
# ### 8.3 pandas

# %% [markdown]
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %% [markdown]
# ## 9. 데이터 시각화를 위한 폰트 설정

# %%
def get_font_family():
    """
    시스템 환경에 따른 기본 폰트명을 반환하는 함수
    """
    import platform
    system_name = platform.system()
    # colab 사용자는 system_name이 'Linux'로 확인

    if system_name == "Darwin" :
        font_family = "AppleGothic"
    elif system_name == "Windows":
        font_family = "Malgun Gothic"
    else:
        # Linux
        # colab에서는 runtime을 <꼭> 재시작 해야합니다.
        # 런타임을 재시작 하지 않고 폰트 설치를 하면 기본 설정 폰트가 로드되어 한글이 깨집니다.
        # !apt-get update -qq
        # !apt-get install fonts-nanum -qq  > /dev/null

        import matplotlib.font_manager as fm

        fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
        font = fm.FontProperties(fname=fontpath, size=9)
        fm._rebuild()
        font_family = "NanumBarunGothic"
    return font_family

# %%
# 위에서 만든 함수를 통해 시스템 폰트를 불러옵니다
get_font_family()
# Out:
# 'Malgun Gothic'

# %%
# 시각화를 위한 폰트 설정
# 위에서 만든 함수를 통해 시스템 폰트를 불러와서 font_family라는 변수에 할당합니다
import matplotlib.pyplot as plt

font_family = get_font_family()
# 폰트 설정
plt.rc("font", family = font_family)
# 마이너스 폰트 설정
plt.rc("axes", unicode_minus = False)

# ggplot 으로 그래프 스타일 설정
plt.style.use("ggplot")
# 다른 스타일도 있음. plt.style.use <- 검색해서 알아볼것임

# 그래프에 retina display 적용
# retina display가 있는 노트북에서 사용가능함( 잘보이는 효과.. )
from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

# %% [markdown]
# ### 9.1 폰트 설정 확인하기

# %%
# 한글 폰트 확인하기
pd.Series([1,3,5,-7,9]).plot(title = "한글폰트")

# %% [markdown]
# ## 10. 한개의 변수 빈도수 구하고 시각화 하기

# %% [markdown]
# * Keyword
#     * Series.value_counts()
#         - 시리즈 데이터의 빈도수를 구하기 위함
#     * Series.value_counts().plot()
#         - 선그래프 그리기
#     * Series.value_counts().plot.bar()
#         - 막대 그래프 그리기
#     * Series.value_counts().plot.barh()
#         - 가로 축 막대 그래프 그리기
#     * sns.countplot()
#         - seaborn으로도 가능, value_counts 과정을 생략하고 적용가능

# %% [markdown]
# ## Market
# * KOSPI (Korea Composite Stock Price Index)
#     * 우리나라의 종합주가지수(KOSPI)는 증권거래소가 1964.1.4일을 기준시점으로 다우존스식 주가평균을 지수화한 수정주가 평균지수를 산출, 발표하기 시작하였다. 다우존스식 주가지수는 주가지수를 구성하는 상장종목 중 일부 우량주만을 선정하여 산출하는 방식이다. 시가총액식 주가지수는 일정시점의 시가총액과 현재시점의 시가총액을 대비, 현재의 주가수준을 판단하는 방식이다. 즉, 지난 1980년 1월 4일 기준 상장종목 전체의 시가총액을 100으로 보고 현재 상장종목들의 시가총액이 어느 수준에 놓여 있는지를 보여주는 시스템이다.
#     * 종합주가지수 = (비교시점의 시가총액 ÷ 기준시점의 시가총액) × 100
#     * 출처 : [네이버 지식백과] 종합주가지수 (시사상식사전, pmg 지식엔진연구소) https://terms.naver.com/entry.nhn?docId=72147&cid=43667&categoryId=43667
#
#
# * KOSDAQ (Korea Securities Dealers Automated Quotation)
#     * 미국의 나스닥(NASDAQ)을 한국식으로 합성한 용어로 1996년 7월 1일 증권업협회와 증권사들이 설립한 코스닥증권(주)에 의하여 개설되었다. 코스닥의 개장으로 단순히 증권거래소 상장을 위한 예비적 단계였던 장외시장이 미국의 나스닥(NASDAQ)과 같이 자금조달 및 투자시장으로 독립적인 역할을 수행하게 되었다. 이후 2005년 1월 유가증권시장, 코스닥시장, 선물시장이 증권선물거래소(현 한국거래소)로 통합됨에 따라 코스닥시장도 거래소가 개설한 정규시장으로 편입되었다. 코스닥은 유가증권시장에 비해 진입요건이 상대적으로 덜 까다롭기 때문에 주로 중소벤처기업들이 상장되어 있다.
#     * 출처 : [네이버 지식백과] KOSDAQ (매일경제, 매경닷컴) https://terms.naver.com/entry.nhn?docId=18639&cid=43659&categoryId=43659
#
#
# * KONEX(Korea New Exchange) :
#     * 일정 요건을 갖춘 비상장 기업에 문호를 개방하기 위해 개설하는 유가증권시장, 코스닥시장에 이은 제3의 주식시장을 일컫는다. 코넥스시장은 우수한 기술력을 보유하고 있음에도 불구하고, 짧은 경력 등을 이유로 자금 조달에 어려움을 겪는 초기 중소기업과 벤처기업이 자금을 원활하게 조달할 수 있도록 하기 위해 설립된 자본시장으로, 2013년 7월 1일 개장되었다.
#     * 출처 : [네이버 지식백과] 코넥스 (시사상식사전, pmg 지식엔진연구소) https://terms.naver.com/entry.nhn?docId=1006691&cid=43667&categoryId=43667

# %%
# Market column에 어떤 데이터들이 있는지 확인합니다.
# 시리즈 형태의 데이터로 Market만 가지고옴
# df["Market"]
df["Market"].unique()
# Out:
# array(['KOSDAQ', 'KOSPI', 'KONEX'], dtype=object)

# %%
# 빈도수 확인
df["Market"].value_counts()
# Out:
# KOSDAQ    1471
# KOSPI      998
# KONEX      143
# Name: Market, dtype: int64

# %%
df["Market"].value_counts().plot.barh()

# %%
# seaborn countplot 활용하여 빈도수를 표현합니다
import seaborn as sns
sns.countplot(data = df, y = "Market")

# %% [markdown]
# ### 10.2 Sector

# %%
# 섹터의 빈도수를 구합니다.
# 상위 30개 섹터의 빈도수를 sector_count_top 변수에 할당합니다.
sector_count_top = df["Sector"].value_counts().head(30)
sector_count_top
# Out:
# 특수 목적용 기계 제조업                            141
# 소프트웨어 개발 및 공급업                           135
# 전자부품 제조업                                 121
# 자동차 신품 부품 제조업                             97
# 의약품 제조업                                   93
# 기타 금융업                                    92
# 기타 화학제품 제조업                               90
# 통신 및 방송 장비 제조업                            72
# 금융 지원 서비스업                                71
# 반도체 제조업                                   57
# 1차 철강 제조업                                 57
# 자연과학 및 공학 연구개발업                           53
# 의료용 기기 제조업                                50
# 일반 목적용 기계 제조업                             44
# 기초 화학물질 제조업                               43
# 플라스틱제품 제조업                                43
# 기타 전문 도매업                                 42
# 기초 의약물질 및 생물학적 제제 제조업                     38
# 컴퓨터 프로그래밍, 시스템 통합 및 관리업                   35
# 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업         34
# 영화, 비디오물, 방송프로그램 제작 및 배급업                 34
# 기타 식품 제조업                                 33
# 의료용품 및 기타 의약 관련제품 제조업                     29
# 봉제의복 제조업                                  28
# 기계장비 및 관련 물품 도매업                          24
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외     24
# 기타 금속 가공제품 제조업                            23
# 건물 건설업                                    23
# 구조용 금속제품, 탱크 및 증기발생기 제조업                  20
# 생활용품 도매업                                  19
# Name: Sector, dtype: int64

# %%
sector_count_top.plot.barh(figsize = (10, 10), title = "Sector의 빈도수")

# %%
# df[df["Sector"].isin(sector_count_top.index)]

# %%
# Seaborn countplot 활용하여 빈도수를 구합니다
plt.figure(figsize=(10,11))
sns.countplot(data = df[df["Sector"].isin(sector_count_top.index)],
              y = "Sector", palette="Blues_r",
              order = sector_count_top.index)

# %%
# 빈도수가 가장 많은 데이터 색인하기
df[df["Sector"] == "특수 목적용 기계 제조업"]
# Out:
#       Symbol  Market     Name         Sector  \
# 0     060310  KOSDAQ       3S  특수 목적용 기계 제조업
# 4     265520  KOSDAQ    AP시스템  특수 목적용 기계 제조업
# 35    068790  KOSDAQ      DMS  특수 목적용 기계 제조업
# 53    083450  KOSDAQ      GST  특수 목적용 기계 제조업
# 60    078150  KOSDAQ  HB테크놀러지  특수 목적용 기계 제조업
# ...      ...     ...      ...            ...
# 2573  010660   KOSPI     화천기계  특수 목적용 기계 제조업
# 2574  000850   KOSPI     화천기공  특수 목적용 기계 제조업
# 2590  090710  KOSDAQ     휴림로봇  특수 목적용 기계 제조업
# 2604  010240  KOSDAQ       흥국  특수 목적용 기계 제조업
# 2611  238490  KOSDAQ       힘스  특수 목적용 기계 제조업
#
#                                                Industry ListingDate  \
# 0                                           반도체 웨이퍼 캐리어  2002-04-23
# 4                                           디스플레이 제조 장비  2017-04-07
# 35                                             LCD 제조장비  2004-10-01
# 53                                  GasScrubber,Chiller  2006-02-01
# 60                                          TFT-LCD검사장비  2004-12-08
# ...                                                 ...         ...
# 2573  선반,밀링,연삭기,CNC선반,CNC밀링,머시닝센타 제조,판매/자동차부품(실린더블럭) 제조  1988-12-12
# 2574  CNC선반,CNC밀링,연마기(금속공작기계),MC공작기계,COPY밀링기계,주방품 제조,도매  1999-11-18
# 2590                                       제조업용로봇및서비스로봇  2006-12-05
# 2604                                  굴삭기 Roller 및 형단조품  2009-05-12
# 2611                     OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20
#
#      SettleMonth      Representative                    HomePage Region  \
# 0            03월  박종익, 김세완 (각자 대표이사)        http://www.3sref.com  서울특별시
# 4            12월                 김영주  http://www.apsystems.co.kr    경기도
# 35           12월                 박용석      http://www.dms21.co.kr    경기도
# 53           12월                 김덕준       http://www.gst-in.com    경기도
# 60           12월                 문성준     http://www.ncbnet.co.kr   충청남도
# ...          ...                 ...                         ...    ...
# 2573         12월            권영열, 권형석   http://www.hwacheon.co.kr  서울특별시
# 2574         12월     각자대표이사 권영두, 권영렬     http://www.hwacheon.com  광주광역시
# 2590         12월                 정광원     http://www.dstrobot.com   충청남도
# 2604         12월                 류명준   http://www.heungkuk.co.kr   충청남도
# 2611         12월                 김주환       http://www.hims.co.kr  인천광역시
#
#       ListingYear
# 0          2002.0
# 4          2017.0
# 35         2004.0
# 53         2006.0
# 60         2004.0
# ...           ...
# 2573       1988.0
# 2574       1999.0
# 2590       2006.0
# 2604       2009.0
# 2611       2017.0
#
# [141 rows x 11 columns]

# %% [markdown]
# ## 10.3 Industry

# %%
# Industry 의 빈도수를 구합니다
df["Industry"].value_counts()
# Out:
# 기업인수합병                                      37
# 지주회사                                        19
# 지주사업                                         9
# 기업 인수 및 합병                                   7
# 화장품                                          7
#                                             ..
# 반도체 및 디스플레이 검사장비 및 검사부품                      1
# 선박,해양구조물,엔진,펌프 전동기,중전기,중장비 제조/자동창고,물류시스템     1
# 자동차부품(CRASH PAD,TRIM PANEL) 제조,판매            1
# 골판지,골판지상자,수출용박스 제조,도매/인쇄                     1
# 외식 프랜차이즈사업 및 식자재 유통                          1
# Name: Industry, Length: 2240, dtype: int64

# %%
# Industry 빈도수를 pandas 의 plot 기능을 사용해 시각화 합니다.
plt.figure(figsize=(10,10))
df["Industry"].value_counts().head(30).plot.barh()

# %%
# sort_values 기능을 사용해 반대로 정렬해서 표시합니다.
df["Industry"].value_counts().head(30).sort_values()
# Out:
# 유가증권 매매,중개,대리,인수                             2
# 디지털셋톱박스                                      2
# 골프시뮬레이터                                      2
# 금융 지원 서비스업                                   2
# 손해보험                                         2
# 카지노                                          2
# 도시가스                                         2
# 합병                                           2
# LED패키지                                       2
# 스킨케어 베이직, 포인트 메이크업, 스킨케어 스페셜, 베이스 메이크업 등     2
# 광고대행                                         2
# 사료                                           2
# 금융지원서비스                                      3
# 도급공사                                         3
# 증권업                                          3
# -                                            3
# 의약품                                          3
# 건강기능식품                                       3
# 자동차부품                                        3
# 금융지주회사                                       3
# 금융지원 서비스                                     3
# 셋톱박스                                         3
# 벤처캐피탈                                        4
# 기업인수 및 합병                                    6
# 모바일게임                                        7
# 화장품                                          7
# 기업 인수 및 합병                                   7
# 지주사업                                         9
# 지주회사                                        19
# 기업인수합병                                      37
# Name: Industry, dtype: int64

# %% [markdown]
# ### 10.4 Region

# %%
# Region의 빈도수를 구합니다.
# value_counts() 통해 지역별 상장회사의 빈도수를 봅니다.
plt.figure(figsize = (10,10))
df['Region'].value_counts().plot.barh()

# %%
df["Region"].value_counts().index
# Out:
# Index(['서울특별시', '경기도', '충청남도', '경상남도', '인천광역시', '충청북도', '부산광역시', '경상북도',
#        '대구광역시', '대전광역시', '전라북도', '강원도', '울산광역시', '광주광역시', '전라남도', '제주특별자치도',
#        '세종특별자치시', '홍콩', '미국', '케이맨 제도', '일본'],
#       dtype='object')

# %%
# Region 의 빈도수를 seaborn 의 countplot으로 그립니다
plt.figure(figsize = (10,10))
sns.countplot(data = df, y = "Region", 
              palette="Blues_r",
              order = df["Region"].value_counts().index).set_title("소재지별 종목 수")
# Out:
# Text(0.5, 1.0, '소재지별 종목 수')

# %%
# order 기능을 통해 빈도수를 정렬합니다

sns.countplot(data = df, y="Region", palette="Blues_r", order = df["Region"].value_counts().index).set_title("소재지별 종목 수")
# Out:
# Text(0.5, 1.0, '소재지별 종목 수')

# %%
# Region 기준으로 정렬

sns.countplot(data = df.sort_values(by = "Region"),
              palette="Greens",
              y = "Region")

# %% [markdown]
# ## 11. 두개의 변수 빈도수 구하고 시각화 하기
# * crosstab 으로 빈도수 구하기
# * seaborn의 countplot 으로 빈도수 시각화
# * pandas의 plot 기능으로 시각화
#     * lineplot : 연속된 데이터(숫자, 기간)
#     * barplot : 비연속 데이터 (범주형)
#     * hist : 연속된 수치 데이터의 범주화

# %% [markdown]
# ### 11.1 지역별 상장 시장 종목 빈도수 구하기
# * pd.crosstab을 통한 2개의 변수에 대한 빈도수 구하기

# %%
# pd.crosstab을 통한 2개의 변수에 대한 빈도수 구하기
# Market 과 Region으로 빈도수 구하기
pd.crosstab(df["Market"], df["Region"])
# Out:
# Region  강원도  경기도  경상남도  경상북도  광주광역시  대구광역시  대전광역시  미국  부산광역시  서울특별시  ...  \
# Market                                                               ...
# KONEX     7   37     0     7      6      1      7   0      1     54  ...
# KOSDAQ   16  492    49    37      9     34     38   5     38    508  ...
# KOSPI     4  145    40    19      9     21      8   0     37    407  ...
#
# Region  울산광역시  인천광역시  일본  전라남도  전라북도  제주특별자치도  충청남도  충청북도  케이맨 제도  홍콩
# Market
# KONEX       0      4   0     3     1        1     4     9       0   0
# KOSDAQ     10     57   3    13    16        2    63    60       4   9
# KOSPI      16     25   0     7    11        7    26    14       1   0
#
# [3 rows x 21 columns]

# %%
# countplot : Market과 Region으로 빈도수 시각화 하기
plt.figure(figsize=(10,10))
sns.countplot(data = df, y="Region", hue = "Market").set_title("Market과 Region으로 빈도수 시각화 하기")
# Out:
# Text(0.5, 1.0, 'Market과 Region으로 빈도수 시각화 하기')

# %% [markdown]
# ### 11.2 연도별 상장 종목 빈도수 분석

# %%
# Market, ListingYear 빈도수 구하기
df_market_year = pd.crosstab(df["Market"], df["ListingYear"])
df_market_year
# Out:
# ListingYear  1956.0  1962.0  1964.0  1966.0  1968.0  1969.0  1970.0  1971.0  \
# Market
# KONEX             0       0       0       0       0       0       0       0
# KOSDAQ            0       0       0       0       0       0       0       0
# KOSPI             5       1       1       1       6       5       4       1
#
# ListingYear  1972.0  1973.0  ...  2011.0  2012.0  2013.0  2014.0  2015.0  \
# Market                       ...
# KONEX             0       0  ...       0       0      13      13      27
# KOSDAQ            0       0  ...      53      20      35      59      90
# KOSPI             3      22  ...      25      14      11       9      18
#
# ListingYear  2016.0  2017.0  2018.0  2019.0  2020.0
# Market
# KONEX            28      19      14      17      12
# KOSDAQ           65      68      90      97      86
# KOSPI            18      20      19      15      14
#
# [3 rows x 56 columns]

# %% [markdown]
# ### 11.3 seaborn을 통한 빈도수 시각화

# %%
# Seaborn countplot 활용하여 빈도수를 표현합니다
# hue 를 상용해 다른 변수를 함께 표현합니다. 
# hue = 색상을 의미
plt.figure(figsize = (15,4))
plt.xticks(rotation = 60)
sns.countplot(data = df, x = "ListingYear", hue="Market")

# %% [markdown]
# ## 11.4 Pandas를 통한 시각화

# %%
# Pandas plot 기능을 활용하여 기본 그래프 (line)를 그립니다
# Pandas plot 으로 그릴 때 x 축에 인덱스 값이 y축에는 컬럼에 있는 값이 들어갑니다
# 컬럼이 여러개라면 다른 색상으로 그려집니다.
df_market_year.T
# 행, 열 변환
df_market_year.T.plot(figsize = (15,10))

# %%
# 컬럼 값을 subplot으로 으립니다

df_market_year.T.plot(subplots = True)

# log출력 안되게 하려면 다른 변수에 넣어서 출력하면됨.
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000015EA18AD580>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000015E9E52D9D0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000015E9EE5F970>],
#       dtype=object)

# %%
# Pandas plot 기능 활용하여 막대 그래프 (bar, barh)를 그립니다.
df_market_year.T.plot.bar(figsize=(15,4))

# %%
# 컬럼명의 데이터 타입을 int으로 변경
df_market_year.columns = df_market_year.columns.astype(int)
df_market_year.T.plot.bar(figsize=(15,4))

# %% [markdown]
# ## 11.5 groupby 와 pivot_table로 빈도수 구하기

# %%
# groupby([인덱스 컬럼 리스트])[연산에 사용할 컬럼].연산()
# reset_index를 통해 DataFrame 형태로 바꿔주자.
df_year_market = df.groupby(["Market", "ListingYear"])["Symbol"].count().reset_index(name = "count")
df_year_market
# Out:
#    Market  ListingYear  count
# 0   KONEX       2013.0     13
# 1   KONEX       2014.0     13
# 2   KONEX       2015.0     27
# 3   KONEX       2016.0     28
# 4   KONEX       2017.0     19
# ..    ...          ...    ...
# 91  KOSPI       2016.0     18
# 92  KOSPI       2017.0     20
# 93  KOSPI       2018.0     19
# 94  KOSPI       2019.0     15
# 95  KOSPI       2020.0     14
#
# [96 rows x 3 columns]

# %%
# pivot_table로 같은 결과가 나오게 연산하기
# pivot - 데이터프레임 형태만 바꿈
# 
df_year_market = pd.pivot_table(data = df, index = ["ListingYear", "Market"],values="Symbol", aggfunc="count")
df_year_market = df_year_market.reset_index()
df_year_market = df_year_market.rename(columns = {"Symbol" : "count"})
df_year_market
# Out:
#     ListingYear  Market  count
# 0        1956.0   KOSPI      5
# 1        1962.0   KOSPI      1
# 2        1964.0   KOSPI      1
# 3        1966.0   KOSPI      1
# 4        1968.0   KOSPI      6
# ..          ...     ...    ...
# 91       2019.0  KOSDAQ     97
# 92       2019.0   KOSPI     15
# 93       2020.0   KONEX     12
# 94       2020.0  KOSDAQ     86
# 95       2020.0   KOSPI     14
#
# [96 rows x 3 columns]

# %%
# 위의 group by 결과를 scatterplot으로 그립니다
plt.figure(figsize = (15,4))
sns.scatterplot(data = df_year_market, x = "ListingYear", y = "count", hue = "Market",
               size = "count")

# %%
# lineplot 그리기
# bootstrap = 샘플뽑기 
plt.figure(figsize = (15,4))
sns.lineplot(data = df_year_market, x = "ListingYear", y = "count", hue = "Market", ci = None)

# %%
# relplot으로 subplot 그리기 - scatter
# rel = relation 두 수치 데이터에 대한 관계를 표시하는 것
# col / row = subplot
sns.relplot(data = df_year_market, x = "ListingYear", y = "count", col = "Market",
           hue = "Market")

# %%
# replot으로 subplot 그리기 - line
sns.relplot(data = df_year_market, x = "ListingYear", y = "count", col = "Market",
           hue = "Market", kind = "line")

# %% [markdown]
# ## 11.6 구간화 binning과 히스토그램
# * 연속된 수치 데이터를 범주형 데이터로 표현, bucketing 이라고 부르기도 함
# * 히스토그램 : 도수 분포를 그래프 형태로 표현한 것
# * 막대 그래프와 비슷해 보이지만 다른 그래프

# %%
# bins 의 갯수에 따라 그래프의 표현 방법이 달라집니다.
# 구간을 잘게 나눌 수 있음.*
# 기본값은 10임
df["ListingYear"].plot.hist(bins = 10, figsize = (10,4), title = "상장 연도")

# %% [markdown]
# * 오른쪽으로 치우쳐 있는걸로 봐선, 최근에 많이 상장한듯함

# %% [markdown]
# ## 12. 데이터 색인

# %%
# 케이맨 제도에 있는 회사 찾기
df[df["Region"] == "케이맨 제도"]
# Out:
#       Symbol  Market      Name   Sector  \
# 283   900280  KOSDAQ     골든센츄리   기타 금융업
# 317   900070  KOSDAQ    글로벌에스엠   기타 금융업
# 1249  900120  KOSDAQ    씨케이에이치   기타 금융업
# 1501  900140   KOSPI  엘브이엠씨홀딩스  자동차 판매업
# 2138  900250  KOSDAQ   크리스탈신소재   기타 금융업
#
#                                     Industry ListingDate SettleMonth  \
# 283                             트랙터용 휠 및 타이어  2016-10-19         12월
# 317   자회사 제품 : IT기기용 정밀 화스너부품(스크류, 샤프트, 스프링)  2009-12-23         12월
# 1249                                  건강보조식품  2010-03-31         06월
# 1501                                    지주회사  2010-11-30         12월
# 2138                     합성운모 플레이크, 파우더, 테이프  2016-01-28         12월
#
#                Representative                           HomePage  Region  \
# 283                       주승화         http://www.jsj-wheel.co.kr  케이맨 제도
# 317                       나윤복        http://www.globalsmtech.com  케이맨 제도
# 1249                      린진성                                NaN  케이맨 제도
# 1501  오세영, 노성석, 김선발 (각자 대표이사)        http://www.lvmcholdings.net  케이맨 제도
# 2138    다이중치우 (DAI ZHONG QIU)  http://www.crystalnewmaterial.com  케이맨 제도
#
#       ListingYear
# 283        2016.0
# 317        2009.0
# 1249       2010.0
# 1501       2010.0
# 2138       2016.0

# %%
# 1970년 이전에 상장한 기업을 찾습니다.
df[df["ListingYear"] < 1970]
# Out:
#       Symbol Market       Name                     Sector  \
# 15    000120  KOSPI     CJ대한통운                  도로 화물 운송업
# 34    001530  KOSPI       DI동일                     상품 중개업
# 162   004250  KOSPI        NPC                 플라스틱제품 제조업
# 266   000050  KOSPI         경방                     종합 소매업
# 526   001440  KOSPI       대한전선              절연선 및 케이블 제조업
# 528   001790  KOSPI       대한제당       곡물가공품, 전분 및 전분제품 제조업
# 531   003490  KOSPI       대한항공                  항공 여객 운송업
# 779   000060  KOSPI      메리츠화재                        보험업
# 981   000070  KOSPI      삼양홀딩스                     기타 금융업
# 1078  002420  KOSPI       세기상사  영화, 비디오물, 방송프로그램 제작 및 배급업
# 1088  003030  KOSPI     세아제강지주                     기타 금융업
# 1688  000700  KOSPI      유수홀딩스        회사 본부 및 경영 컨설팅 서비스업
# 1717  000100  KOSPI       유한양행                    의약품 제조업
# 1879  000950  KOSPI         전방               방적 및 가공사 제조업
# 2076  003690  KOSPI       코리안리                      재 보험업
# 2401  000970  KOSPI      한국주철관                  1차 철강 제조업
# 2412  000240  KOSPI  한국테크놀로지그룹                     기타 금융업
# 2471  003300  KOSPI      한일홀딩스   시멘트, 석회, 플라스터 및 그 제품 제조업
# 2479  003480  KOSPI   한진중공업홀딩스          연료용 가스 제조 및 배관공급업
#
#                                                Industry ListingDate  \
# 15    Contract Logistics, 포워딩, 항만하역, 해운, 택배국제특송, SCM...  1956-07-02
# 34                    면사,화섬사,면포,혼방포,스포츠웨어용 신합섬 제조,도매,수출  1964-01-04
# 162                   산업용기프라스틱제품(플라스틱 파렛트,시트 파렛트) 제조,판매  1969-09-08
# 266           섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03
# 526   전력선,통신케이블,적산계기,스텐레스압연제품,광케이블,초고압선,알루미늄 제조,도매/전기공사  1968-12-27
# 528    제당,가축용 배합사료,설탕,기능성감미료(자일로올리고당),외식산 제조,도소매/부동산 임대  1968-12-27
# 531            여객운송,화물운송,항공기 제조,판매,정비수리/기내식 제조판매,면세품 판매  1966-03-18
# 779                                    손해보험(화재,해상,운송보험)  1956-07-02
# 981                                        지주회사,경영자문컨설팅  1968-12-27
# 1078           극장(영화상영)/극영화,만화영화 제조/음식료품,일용잡화 소매/부동산 임대  1968-12-27
# 1088                                             경영컨설팅업  1969-05-13
# 1688                                               지주사업  1956-03-03
# 1717  의약품(삐콤씨,알마겔,세파졸린주사,아코텍스주사,이세파신,신생아호흡곤란치료제 등),생...  1962-11-01
# 1879  면사,면혼방사,마혼방사,화섬사,염색사,자수사,소모사,면직물,면혼방직물,화섬직물,특수...  1968-10-21
# 2076                                        금융보험/부동산 임대  1969-12-22
# 2401                                       수도용주철관,강관 제조  1969-12-12
# 2412                                            비금융지주회사  1968-12-27
# 2471                                               지주사업  1969-11-20
# 2479                                               지주회사  1956-03-03
#
#      SettleMonth              Representative  \
# 15           12월                         박근희
# 34           12월                    서태원, 손재선
# 162          12월                         최병민
# 266          12월                      김준, 김담
# 526          12월                         나형균
# 528          12월                         김기영
# 531          12월                    조원태, 우기홍
# 779          12월                         김용범
# 981          12월                         윤재엽
# 1078         12월                         김정희
# 1088         12월                    이순형, 남형근
# 1688         12월                         송영규
# 1717         12월                    대표이사 이정희
# 1879         12월                    조규옥, 김형건
# 2076         12월                         원종규
# 2401         03월  홍동국, 김태형, 김형규, 김길출 (각자대표제)
# 2412         12월           조현식, 조현범(각자 대표이사)
# 2471         12월              허기호, 전근식(각자대표)
# 2479         12월                    조남호, 조원국
#
#                                           HomePage Region  ListingYear
# 15                      http://www.cjlogistics.com  서울특별시       1956.0
# 34                          http://www.dong-il.com  서울특별시       1964.0
# 162                           http://www.npc.co.kr    경기도       1969.0
# 266                     http://www.kyungbang.co.kr  서울특별시       1956.0
# 526                          http://www.taihan.com    경기도       1968.0
# 528                            http://www.ts.co.kr  인천광역시       1968.0
# 531                       http://www.koreanair.com  서울특별시       1966.0
# 779                      http://www.meritzfire.com  서울특별시       1956.0
# 981                         http://www.samyang.com  서울특별시       1968.0
# 1078                       http://daehancinema.com  서울특별시       1968.0
# 1088  http://www.seahsteel.co.kr/company/holdings/  서울특별시       1969.0
# 1688                  http://www.eusu-holdings.com  서울특별시       1956.0
# 1717                        http://www.yuhan.co.kr  서울특별시       1962.0
# 1879                     http://www.chonbang.co.kr  서울특별시       1968.0
# 2076                     http://www.koreanre.co.kr  서울특별시       1969.0
# 2401                         http://www.kcip.co.kr  부산광역시       1969.0
# 2412        http://www.hankook-technologygroup.com    경기도       1968.0
# 2471                          http://www.hanil.com  서울특별시       1969.0
# 2479                  http://www.hhic-holdings.com    경기도       1956.0

# %%
# 2020년 상장한 서울특별시에 소재한 코스피 종목을 찾습니다.
df[(df["ListingYear"] == 2020) & 
   (df["Region"] == "서울특별시") & 
   (df["Market"] == "KOSPI")]
# Out:
#       Symbol Market        Name            Sector                    Industry  \
# 44    365550  KOSPI  ESR켄달스퀘어리츠      부동산 임대 및 공급업                       부동산투자
# 824   357250  KOSPI    미래에셋맵스리츠      부동산 임대 및 공급업                     부동산 임대업
# 932   352820  KOSPI         빅히트  오디오물 출판 및 원판 녹음업  음악 기획/제작, 퍼블리싱, 아티스트 매니지먼트
# 1451  244920  KOSPI     에이플러스에셋    보험 및 연금관련 서비스업                  보험대리 및 중개업
# 1795  350520  KOSPI   이지스레지던스리츠      부동산 임대 및 공급업           부동산투자, 취득, 매매, 임대
# 1800  334890  KOSPI     이지스밸류리츠      부동산 임대 및 공급업           부동산투자, 취득, 매매, 임대
# 1904  348950  KOSPI    제이알글로벌리츠      부동산 임대 및 공급업                 벨기에 파이낸스 타워
# 2033  344820  KOSPI     케이씨씨글라스     유리 및 유리제품 제조업                       판유리 등
# 2065  357120  KOSPI    코람코에너지리츠      부동산 임대 및 공급업                 부동산 투자 및 관리
# 2213  363280  KOSPI      티와이홀딩스            기타 금융업                        지주사업
#
#      ListingDate SettleMonth Representative  \
# 44    2020-12-23         05월            박래익
# 824   2020-08-05         11월            김호식
# 932   2020-10-15         12월            방시혁
# 1451  2020-11-20         12월            박경순
# 1795  2020-08-05         06월            박영희
# 1800  2020-07-16         08월            도병운
# 1904  2020-08-07         06월            오남수
# 2033  2020-01-21         12월            김내환
# 2065  2020-08-31         11월            이성균
# 2213  2020-09-22         12월            유종연
#
#                                  HomePage Region  ListingYear
# 44              http://www.esrks-reit.com  서울특별시       2020.0
# 824   http://www.maps1reit.miraeasset.com  서울특별시       2020.0
# 932             http://www.bighitcorp.com  서울특별시       2020.0
# 1451                                  NaN  서울특별시       2020.0
# 1795        http://igisresidencereit.com/  서울특별시       2020.0
# 1800         http://www.igisvaluereit.com  서울특별시       2020.0
# 1904              http://jrglobalreit.com  서울특별시       2020.0
# 2033            http://www.kccglass.co.kr  서울특별시       2020.0
# 2065             http://www.koramco.co.kr  서울특별시       2020.0
# 2213         http://www.ty-holdings.co.kr  서울특별시       2020.0

# %% [markdown]
# ### 12.1 지역별 섹터

# %%
# Sector, Region으로 crosstab 연산을 합니다
# df_sr

df_sr = pd.crosstab(df["Sector"], df["Region"])
df_sr
# Out:
# Region               강원도  경기도  경상남도  경상북도  광주광역시  대구광역시  대전광역시  미국  부산광역시  \
# Sector
# 1차 비철금속 제조업            0    7     1     1      0      3      1   0      1
# 1차 철강 제조업              0    4    11     7      1      0      1   0     12
# 가구 제조업                 0    4     0     0      0      0      0   0      0
# 가전제품 및 정보통신장비 소매업      0    0     0     0      0      1      0   0      0
# 가정용 기기 제조업             0    6     1     0      1      0      0   0      0
# ...                  ...  ...   ...   ...    ...    ...    ...  ..    ...
# 해상 운송업                 0    0     0     0      0      0      0   0      0
# 해체, 선별 및 원료 재생업        0    1     0     0      0      0      0   0      0
# 화학섬유 제조업               0    1     0     1      0      1      0   0      0
# 환경 정화 및 복원업            0    0     0     0      0      0      0   0      0
# 회사 본부 및 경영 컨설팅 서비스업    0    1     0     0      0      1      0   0      2
#
# Region               서울특별시  ...  울산광역시  인천광역시  일본  전라남도  전라북도  제주특별자치도  충청남도  \
# Sector                      ...
# 1차 비철금속 제조업              3  ...      0      0   0     0     0        0     1
# 1차 철강 제조업               11  ...      0      4   0     1     1        0     4
# 가구 제조업                   3  ...      0      1   0     0     0        0     0
# 가전제품 및 정보통신장비 소매업        1  ...      0      0   0     0     0        0     0
# 가정용 기기 제조업               1  ...      0      0   0     0     0        0     0
# ...                    ...  ...    ...    ...  ..   ...   ...      ...   ...
# 해상 운송업                   5  ...      0      0   0     0     0        0     0
# 해체, 선별 및 원료 재생업          0  ...      0      0   0     0     0        0     0
# 화학섬유 제조업                 6  ...      0      0   0     0     1        0     0
# 환경 정화 및 복원업              0  ...      0      0   0     0     0        0     1
# 회사 본부 및 경영 컨설팅 서비스업      7  ...      0      0   0     0     0        0     0
#
# Region               충청북도  케이맨 제도  홍콩
# Sector
# 1차 비철금속 제조업             0       0   0
# 1차 철강 제조업               0       0   0
# 가구 제조업                  0       0   0
# 가전제품 및 정보통신장비 소매업       0       0   0
# 가정용 기기 제조업              0       0   0
# ...                   ...     ...  ..
# 해상 운송업                  0       0   0
# 해체, 선별 및 원료 재생업         0       0   0
# 화학섬유 제조업                0       0   0
# 환경 정화 및 복원업             0       0   0
# 회사 본부 및 경영 컨설팅 서비스업     0       0   0
#
# [158 rows x 21 columns]

# %% [markdown]
# ### 12.2 컬럼과 인덱스 값으로 색인하기

# %%
# 특정 컬럼만 가져오기
df_sr[["서울특별시","경기도","인천광역시"]]
# Out:
# Region               서울특별시  경기도  인천광역시
# Sector
# 1차 비철금속 제조업              3    7      0
# 1차 철강 제조업               11    4      4
# 가구 제조업                   3    4      1
# 가전제품 및 정보통신장비 소매업        1    0      0
# 가정용 기기 제조업               1    6      0
# ...                    ...  ...    ...
# 해상 운송업                   5    0      0
# 해체, 선별 및 원료 재생업          0    1      0
# 화학섬유 제조업                 6    1      0
# 환경 정화 및 복원업              0    0      0
# 회사 본부 및 경영 컨설팅 서비스업      7    1      0
#
# [158 rows x 3 columns]

# %% [markdown]
# ### 12.3 특정 행만 가져오기
# * .loc[행]
# * .loc[행, 열]
# * .loc[조건식, 열]

# %%
# df_sr에서 소프트웨어 개발 및 공급업 행만 가져오기
df_sr.loc["소프트웨어 개발 및 공급업"].sort_values(ascending = False)
# Out:
# Region
# 서울특별시      89
# 경기도        38
# 충청북도        2
# 일본          2
# 홍콩          1
# 부산광역시       1
# 광주광역시       1
# 대전광역시       1
# 경상남도        0
# 경상북도        0
# 대구광역시       0
# 미국          0
# 세종특별자치시     0
# 케이맨 제도      0
# 울산광역시       0
# 인천광역시       0
# 전라남도        0
# 전라북도        0
# 제주특별자치도     0
# 충청남도        0
# 강원도         0
# Name: 소프트웨어 개발 및 공급업, dtype: int64

# %%
# loc로 행인덱스 가져오기
# 행에서 "소프트웨어 개발 및 공급업", "금융 지원 서비스업", "의약품 제조업" 가져오기
df_sr.loc[["소프트웨어 개발 및 공급업", "금융 지원 서비스업", "의약품 제조업"]]
# Out:
# Region          강원도  경기도  경상남도  경상북도  광주광역시  대구광역시  대전광역시  미국  부산광역시  서울특별시  \
# Sector
# 소프트웨어 개발 및 공급업    0   38     0     0      1      0      1   0      1     89
# 금융 지원 서비스업        0    0     0     0      0      0      0   0      0     71
# 의약품 제조업           5   35     1     0      0      0      2   0      1     38
#
# Region          ...  울산광역시  인천광역시  일본  전라남도  전라북도  제주특별자치도  충청남도  충청북도  \
# Sector          ...
# 소프트웨어 개발 및 공급업  ...      0      0   2     0     0        0     0     2
# 금융 지원 서비스업      ...      0      0   0     0     0        0     0     0
# 의약품 제조업         ...      0      2   0     0     0        0     2     5
#
# Region          케이맨 제도  홍콩
# Sector
# 소프트웨어 개발 및 공급업       0   1
# 금융 지원 서비스업           0   0
# 의약품 제조업              0   0
#
# [3 rows x 21 columns]

# %%
# loc로 행, 컬럼 가져오기
# 행에서 "소프트웨어 개발 및 공급업", "금융 지원 서비스업", "의약품 제조업"
# 열에서 "서울특별시" 가져오기
df_sr.loc[["소프트웨어 개발 및 공급업", "금융 지원 서비스업", "의약품 제조업"], "서울특별시"]
# Out:
# Sector
# 소프트웨어 개발 및 공급업    89
# 금융 지원 서비스업        71
# 의약품 제조업           38
# Name: 서울특별시, dtype: int64

# %%
# loc로 여러 행과 열 가져오기
df_sr.loc[["소프트웨어 개발 및 공급업", "금융 지원 서비스업", "의약품 제조업"],
          ["서울특별시","경기도","인천광역시"]]
# Out:
# Region          서울특별시  경기도  인천광역시
# Sector
# 소프트웨어 개발 및 공급업     89   38      0
# 금융 지원 서비스업         71    0      0
# 의약품 제조업            38   35      2

# %%
# "소프트웨어 개발 및 공급업" 만 가져와서 막대그래프를 그립니다.
plt.figure(figsize = (10,6))
df_sr.loc["소프트웨어 개발 및 공급업"].sort_values(ascending = True).plot.barh()

# %%
# "의약품 제조업" 만 가져와서 막대 그래프
plt.figure(figsize = (10,6))
df_sr.loc["의약품 제조업"].sort_values(ascending = True).plot.barh()

# %%
# 인덱스 순서로 인덱싱을 하고 싶다면?
# df_sr.iloc[행, 열] 혹은 행만 적을 수 있음
df_sr.iloc[-5:, -5:]
# Out:
# Region               제주특별자치도  충청남도  충청북도  케이맨 제도  홍콩
# Sector
# 해상 운송업                     0     0     0       0   0
# 해체, 선별 및 원료 재생업            0     0     0       0   0
# 화학섬유 제조업                   0     0     0       0   0
# 환경 정화 및 복원업                0     1     0       0   0
# 회사 본부 및 경영 컨설팅 서비스업        0     0     0       0   0
